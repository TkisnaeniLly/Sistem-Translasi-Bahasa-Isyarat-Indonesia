# %%
from sklearn.model_selection import train_test_split
import os
import shutil

data_dir = 'dataset_ready'
train_dir = 'data/train'
test_dir = 'data/test'

os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

for label in os.listdir(data_dir):
    files = os.listdir(os.path.join(data_dir, label))
    train_files, test_files = train_test_split(files, test_size=0.2, random_state=42)
    
    os.makedirs(os.path.join(train_dir, label), exist_ok=True)
    os.makedirs(os.path.join(test_dir, label), exist_ok=True)
    
    for f in train_files:
        shutil.copy(os.path.join(data_dir, label, f), os.path.join(train_dir, label, f))
    for f in test_files:
        shutil.copy(os.path.join(data_dir, label, f), os.path.join(test_dir, label, f))
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[1], line 13
#      10 os.makedirs(test_dir, exist_ok=True)
#      12 for label in os.listdir(data_dir):
# ---> 13     files = os.listdir(os.path.join(data_dir, label))
#      14     train_files, test_files = train_test_split(files, test_size=0.2, random_state=42)
#      16     os.makedirs(os.path.join(train_dir, label), exist_ok=True)
#
# NotADirectoryError: [WinError 267] The directory name is invalid: 'dataset_ready\\hand_landmarks.csv'
